# %%
import sys
sys.argv = ["hello", 10]
# %run 01_template.ipynb -- bb 10 # -- là argument truyền vào notebook/script
# Out:
# Hello, param_d = 50
# Hello, a = 20, b = 30
# ['hello', 10]

# %%
param_d
# Out:
# 50

# %%
aa
# Out:
# 120
