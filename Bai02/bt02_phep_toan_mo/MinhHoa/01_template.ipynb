# %%
param_d = 50

# %%
# %run 01_utils.py

# %%
print(f"Hello, param_d = {param_d}")
print(f"Hello, a = {a}, b = {b}")
# Out:
# Hello, param_d = 50
# Hello, a = 20, b = 30

# %%
import sys

# %%
print(sys.argv)
# Out:
# ['/home/codespace/.local/lib/python3.12/site-packages/ipykernel_launcher.py', '--f=/home/codespace/.local/share/jupyter/runtime/kernel-v3583eb578c1e3281da32dea47593b922946fcc9db.json']
